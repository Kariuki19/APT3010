# %% [markdown]
# <a href="https://colab.research.google.com/github/Kariuki19/APT3010/blob/main/IrisData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import os
import pandas as pd
import numpy as np

# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data -O Iris_Data.csv

data_path = ['/content']

filepath = os.sep.join(data_path + ['Iris_Data.csv'])
data = pd.read_csv(filepath)
data.head()
# Out:
# --2024-07-23 19:48:42--  https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘Iris_Data.csv’
#
# Iris_Data.csv           [ <=>                ]   4.44K  --.-KB/s    in 0s
#
# 2024-07-23 19:48:42 (64.8 MB/s) - ‘Iris_Data.csv’ saved [4551]
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
data.shape
# Out:
# (149, 5)

# %%
data.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
data.columns.tolist()
# Out:
# ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa']

# %%
data.dtypes
# Out:
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
data.tail(5)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
data.sample(10)
# Out:
#      5.1  3.5  1.4  0.2      Iris-setosa
# 91   5.8  2.6  4.0  1.2  Iris-versicolor
# 52   5.5  2.3  4.0  1.3  Iris-versicolor
# 142  6.8  3.2  5.9  2.3   Iris-virginica
# 129  7.4  2.8  6.1  1.9   Iris-virginica
# 117  7.7  2.6  6.9  2.3   Iris-virginica
# 20   5.1  3.7  1.5  0.4      Iris-setosa
# 121  7.7  2.8  6.7  2.0   Iris-virginica
# 126  6.1  3.0  4.9  1.8   Iris-virginica
# 53   6.5  2.8  4.6  1.5  Iris-versicolor
# 108  7.2  3.6  6.1  2.5   Iris-virginica

# %%
data['species'] = data.species.apply(lambda r:r.replace('Iris-', ''))

# %%
data.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
data.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
stats_df = data.describe()
stats_df
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
stats_df.loc['range'] = stats_df.loc['max'] - stats_df.loc['min']

# %%
stats_df
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
stats_df.rename({'50%': 'median'}, inplace = True)
stats_df
# Out:
#                5.1         3.5         1.4         0.2
# count   149.000000  149.000000  149.000000  149.000000
# mean      5.848322    3.051007    3.774497    1.205369
# std       0.828594    0.433499    1.759651    0.761292
# min       4.300000    2.000000    1.000000    0.100000
# 25%       5.100000    2.800000    1.600000    0.300000
# median    5.800000    3.000000    4.400000    1.300000
# 75%       6.400000    3.300000    5.100000    1.800000
# max       7.900000    4.400000    6.900000    2.500000
